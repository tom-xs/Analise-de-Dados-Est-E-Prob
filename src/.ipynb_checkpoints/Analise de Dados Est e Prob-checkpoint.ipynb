# %% [markdown]
# # Utilizado python para analise de dados

# %% [markdown]
# primeiramente vamos importar as bibliotecas que serão utilizadas para analisar os dados

# %%
import pandas as pd
import numpy as np
import seaborn as sea               
import matplotlib.pyplot as plt  
from dx import dx

# %% [markdown]
# atribuindo o conjunto de dados que serão analisados para uma variavel

# %%
dados = pd.read_excel("TurmaPM_Grupo_4.xlsx")

# %% [markdown]
# visualização do banco de dados

# %%
dx(dados)
# Out:
#     IDADE SEXO  NOTA BRUTA  NOTA FORMAÇÃO GERAL  NOTA COMPONENTE ESPECÍFICO  \
# 0      25    M        49.3                 56.2                        47.0
# 1      26    M        63.5                 78.3                        58.6
# 2      30    M        36.0                 69.0                        25.0
# 3      34    M        37.1                 55.7                        30.9
# 4      24    M        46.9                 59.9                        42.5
# 5      27    M        30.9                 42.6                        27.0
# 6      26    M        40.3                 45.0                        38.7
# 7      24    M        48.3                 78.6                        38.2
# 8      23    M        62.7                 79.5                        57.1
# 9      25    M        36.2                 59.3                        28.5
# 10     25    F        43.0                 56.0                        38.7
# 11     24    M        51.8                 56.4                        50.3
# 12     27    M        65.1                 86.2                        58.0
# 13     25    F        38.9                 46.6                        36.3
# 14     23    F        21.9                 18.0                        23.2
# 15     23    M        35.3                 60.3                        27.0
# 16     23    M        61.5                 56.9                        63.0
# 17     27    M        41.1                 60.0                        34.8
# 18     21    M        65.0                 61.9                        66.0
# 19     25    M        51.0                 30.0                        58.0
# 20     26    M        39.9                 55.1                        34.8
# 21     26    M        72.7                 82.1                        69.5
# 22     23    M        39.8                 41.6                        39.2
# 23     22    M        66.6                 57.9                        69.5
# 24     23    M        66.1                 76.7                        62.5
# 25     26    M        40.9                 70.9                        30.9
# 26     21    F        46.0                 37.4                        48.8
# 27     23    M        25.9                 22.5                        27.0
# 28     23    M        50.3                 50.5                        50.2
# 29     25    M        39.2                 61.0                        31.9
# 30     31    F        47.5                 51.2                        46.3
# 31     23    M        41.7                 74.1                        30.9
# 32     26    F        39.4                 44.3                        37.8
# 33     20    M        51.9                 62.8                        48.3
# 34     23    M        40.0                 55.4                        34.8
# 35     21    M        47.4                 56.8                        44.2
#
#    CO_RS_I2 CO_RS_I3 CO_RS_I7 CO_RS_I9 QE_I02  ... QE_I59 QE_I60 QE_I61  \
# 0         C        C        C        C      D  ...      7      5      4
# 1         C        C        D        B      D  ...      4      5      4
# 2         D        B        E        C      A  ...      3      5      2
# 3         D        C        B        C      A  ...      5      5      5
# 4         D        C        D        C      D  ...      6      6      6
# 5         E        C        B        C      D  ...      5      5      5
# 6         C        A        D        C      A  ...      4      5      3
# 7         C        D        C        C      A  ...      4      3      2
# 8         C        D        C        D      D  ...      6      6      5
# 9         C        A        E        C      A  ...      4      2      2
# 10        C        A        A        E      A  ...      6      6      6
# 11        D        E        C        C      A  ...      6      6      6
# 12        C        C        B        C      F  ...      5      5      5
# 13        D        C        B        C      D  ...      4      6      6
# 14        D        B        D        B      A  ...      5      4      4
# 15        C        D        D        B      A  ...      5      5      5
# 16        C        C        D        C      A  ...      6      6      3
# 17        D        C        D        C      D  ...      6      6      6
# 18        D        B        E        C      A  ...      6      6      6
# 19        C        B        D        B      D  ...      5      3      5
# 20        A        A        A        A      A  ...      4      4      4
# 21        C        B        E        E      D  ...      4      6      4
# 22        C        C        B        C      A  ...      5      5      4
# 23        C        C        B        D      A  ...      6      5      3
# 24        C        C        A        D      A  ...      4      4      1
# 25        D        B        B        D      D  ...      6      6      6
# 26        E        C        D        E      A  ...      5      5      5
# 27        E        C        E        B      A  ...      1      1      1
# 28        C        C        E        D      D  ...      6      6      5
# 29        C        A        B        E      A  ...      5      5      3
# 30        C        C        B        *      A  ...      4      5      5
# 31        D        B        B        C      D  ...      4      3      4
# 32        C        C        D        C      A  ...      6      6      6
# 33        D        C        E        D      A  ...      2      2      1
# 34        B        C        D        D      B  ...      6      6      6
# 35        C        C        A        D      A  ...      4      4      4
#
#    QE_I62 QE_I63 QE_I64 QE_I65 QE_I66  QE_I67  QE_I68
# 0       7      7      5      7      6       6       2
# 1       4      4      5      4      4       4       2
# 2       2      2      1      2      5       5       2
# 3       4      6      5      5      5       4       2
# 4       5      5      4      3      5       6       3
# 5       5      5      4      1      4       4       1
# 6       2      2      3      3      6       6       4
# 7       1      3      6      1      4       3       3
# 8       5      6      6      6      6       6       3
# 9       2      3      3      1      5       3       3
# 10      6      6      6      6      6       6       6
# 11      6      5      5      1      6       6       6
# 12      6      4      5      4      5       6       4
# 13      6      6      6      6      6       6       6
# 14      2      3      4      1      1       1       2
# 15      5      6      5      5      6       6       4
# 16      6      4      6      3      6       6       4
# 17      6      6      5      6      6       6       4
# 18      6      6      5      4      6       6       3
# 19      4      5      6      1      8       7       5
# 20      4      4      4      4      4       4       4
# 21      4      4      4      4      6       6       5
# 22      5      3      4      7      4       5       1
# 23      3      3      2      2      6       6       1
# 24      3      3      1      1      3       2       2
# 25      6      6      6      6      6       6       4
# 26      4      4      3      5      6       5       2
# 27      1      1      1      1      3       8       8
# 28      5      5      4      6      6       6       6
# 29      3      3      1      1      3       1       2
# 30      5      6      5      5      6       6       4
# 31      5      4      4      3      5       4       1
# 32      6      6      6      6      6       6       6
# 33      1      2      5      2      5       2       1
# 34      6      6      6      6      6       6       6
# 35      5      5      4      1      5       1       1
#
# [36 rows x 60 columns]

# %%
dados.describe()
# Out:
#            IDADE  NOTA BRUTA  NOTA FORMAÇÃO GERAL  NOTA COMPONENTE ESPECÍFICO  \
# count  36.000000   36.000000            36.000000                   36.000000
# mean   24.694444   46.697222            57.130556                   43.205556
# std     2.836693   12.156750            15.858730                   13.527410
# min    20.000000   21.900000            18.000000                   23.200000
# 25%    23.000000   39.350000            49.525000                   31.650000
# 50%    24.500000   44.500000            56.850000                   38.950000
# 75%    26.000000   51.825000            64.350000                   52.000000
# max    34.000000   72.700000            86.200000                   69.500000
#
#           QE_I27     QE_I28     QE_I29     QE_I30     QE_I31     QE_I32  ...  \
# count  36.000000  36.000000  36.000000  36.000000  36.000000  36.000000  ...
# mean    4.694444   4.444444   4.888889   4.888889   4.833333   5.138889  ...
# std     1.190905   1.361605   1.304449   1.236996   1.424279   1.355471  ...
# min     2.000000   1.000000   1.000000   1.000000   1.000000   1.000000  ...
# 25%     4.000000   3.750000   4.000000   4.000000   4.000000   4.750000  ...
# 50%     5.000000   5.000000   5.500000   5.000000   5.000000   6.000000  ...
# 75%     6.000000   6.000000   6.000000   6.000000   6.000000   6.000000  ...
# max     6.000000   6.000000   6.000000   6.000000   6.000000   7.000000  ...
#
#           QE_I59     QE_I60     QE_I61     QE_I62     QE_I63     QE_I64  \
# count  36.000000  36.000000  36.000000  36.000000  36.000000  36.000000
# mean    4.833333   4.805556   4.222222   4.333333   4.416667   4.305556
# std     1.253566   1.327069   1.569552   1.690309   1.518928   1.564233
# min     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
# 25%     4.000000   4.000000   3.000000   3.000000   3.000000   4.000000
# 50%     5.000000   5.000000   4.500000   5.000000   4.500000   5.000000
# 75%     6.000000   6.000000   5.250000   6.000000   6.000000   5.250000
# max     7.000000   6.000000   6.000000   7.000000   7.000000   6.000000
#
#           QE_I65     QE_I66     QE_I67     QE_I68
# count  36.000000  36.000000  36.000000  36.000000
# mean    3.611111   5.166667   4.916667   3.416667
# std     2.101398   1.298351   1.778844   1.857418
# min     1.000000   1.000000   1.000000   1.000000
# 25%     1.000000   4.750000   4.000000   2.000000
# 50%     4.000000   6.000000   6.000000   3.000000
# 75%     6.000000   6.000000   6.000000   4.250000
# max     7.000000   8.000000   8.000000   8.000000
#
# [8 rows x 46 columns]

# %% [markdown]
# utilizando a biblioteca seaborn para 'plotar' graficos

# %%
sns.boxplot(color="yellow" , y=dados['NOTA BRUTA'],width=0.25)

# %%
sns.barplot(x = dados['NOTA BRUTA'], y = dados['IDADE'])

# %%
dados[['NOTA BRUTA','NOTA COMPONENTE ESPECÍFICO','NOTA FORMAÇÃO GERAL']].plot(figsize = (10,8))

# %%
f,(ax1) = plt.subplots(figsize = (8,5))
sea.distplot(dados['NOTA BRUTA'],hist = True,ax = ax1)
